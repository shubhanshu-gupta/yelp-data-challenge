# %%
import json
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_one = []
data_two = []
data_three = []
data_four = []
reviewdata_df = []

# %%
with open('F:\yelp\yelp_academic_dataset_review.json') as f:
    length =  sum(1 for _ in f)
    print length
# Out:
# 2225213

# %%
data_file = open('F:\yelp\yelp_academic_dataset_review.json')
for i, line in enumerate(data_file):
    if i<(length/4):
        data_one.append(json.loads(line))
    elif i>(length/4) and i<(length/2):
        data_two.append(json.loads(line))
    elif i>(length/2) and i<(3*(length/4)):
        data_three.append(json.loads(line))
    elif i>(3*(length/4)) :
        data_four.append(json.loads(line))
data_file.close()

# %%
df = pd.DataFrame(data_one)

# %%
data_main = []
with open('F:\yelp\yelp_academic_dataset_user.json') as f:
    for line in f:
        data_main.append(json.loads(line))

# %%
df_user = pd.DataFrame(data_main)

# %%
merged_df = pd.merge(df, df_user, on='user_id', how='inner')

# %%
merged_df.head(n=1)
# Out:
#               business_id        date               review_id  stars  \
# 0  5UmKMjUEUNdYWqANhGckJw  2012-08-01  Ya85v4eqdd6k9Od8HbQjyA      4
#
#                                                 text  type_x  \
# 0  Mr Hoagie is an institution. Walking in, it do...  review
#
#                   user_id                                  votes_x  \
# 0  PUFPaY9KxDAcGqfsorJp3Q  {u'funny': 0, u'useful': 0, u'cool': 0}
#
#    average_stars                                       compliments elite  \
# 0           3.08  {u'note': 1, u'plain': 1, u'hot': 1, u'more': 1}    []
#
#    fans friends     name  review_count type_y  \
# 0     0      []  Jeffrey            60   user
#
#                                        votes_y yelping_since
# 0  {u'funny': 25, u'useful': 166, u'cool': 12}       2009-05

# %%
merged_df.shape
# Out:
# (556303, 18)

# %%
# read the entire file into a python array
with open('F:\yelp\yelp_academic_dataset_review.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ','.join(data) + "]"

# %%
# read the entire file into a python array
with open('C:\Users\Shubhanshu\Desktop\yelp\\review.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
reviewdata_df = pd.read_json(data_json_str)

# %%
data_main = []
with open('C:\Users\Shubhanshu\Desktop\yelp\\review.json') as f:
    for line in f:
        data_main.append(json.loads(line))

# %%
review_df = pd.DataFrame(data_main)

# %%
review_df
# Out:
#                 business_id        date               review_id  stars  \
# 0    vcNAWiLM4dR7D2nwwJ7nCA  2007-05-17  15SdjuK7DmYqUAj6rjGowg      5
# 1    vcNAWiLM4dR7D2nwwJ7nCA  2010-03-22  RF6UnRTtG7tWMcrO2GEoAg      2
# 2    vcNAWiLM4dR7D2nwwJ7nCA  2012-02-14  -TsVN230RCkLYKBeLsuz7A      4
# 3    vcNAWiLM4dR7D2nwwJ7nCA  2012-03-02  dNocEAyUucjT371NNND41Q      4
# 4    vcNAWiLM4dR7D2nwwJ7nCA  2012-05-15  ebcN2aqmNUuYNoyvQErgnA      4
# 5    vcNAWiLM4dR7D2nwwJ7nCA  2013-04-19  _ePLBPrkrf4bhyiKWEn4Qg      1
# 6    vcNAWiLM4dR7D2nwwJ7nCA  2014-01-02  kMu0knsSUFW2DZXqKkGWlg      5
# 7    vcNAWiLM4dR7D2nwwJ7nCA  2014-01-08  onDPFgNZpMk-bT1zlForRA      5
# 8    vcNAWiLM4dR7D2nwwJ7nCA  2014-08-01  bOJD0Kc3wGioat3oSFqgPQ      1
# 9    vcNAWiLM4dR7D2nwwJ7nCA  2014-12-12  QzjRXUNSGk3PySEcg5y92g      5
# 10   UsFtqoBl7naz8AVUBZMjQQ  2013-11-08  Di3exaUCFNw1V4kSNW5pgA      5
# 11   UsFtqoBl7naz8AVUBZMjQQ  2014-03-29  0Lua2-PbqEQMjD9r89-asw      3
# ...

# %%
data_main1 = []
with open('C:\Users\Shubhanshu\Desktop\yelp\\userdata.json') as f:
    for line in f:
        data_main1.append(json.loads(line))

# %%
user_df = pd.DataFrame(data_main1)

# %%
user_df
# Out:
#       average_stars                                        compliments  \
# 0              4.14  {u'profile': 8, u'cute': 15, u'funny': 11, u'p...
# 1              3.64  {u'profile': 110, u'cute': 209, u'funny': 561,...
# 2              3.59  {u'profile': 9, u'cute': 23, u'funny': 122, u'...
# 3              4.64                                       {u'cute': 2}
# 4              3.80  {u'cute': 2, u'plain': 2, u'writer': 2, u'note...
# 5              4.35  {u'profile': 220, u'cute': 274, u'funny': 1462...
# 6              3.52  {u'profile': 1, u'funny': 1, u'cute': 1, u'pla...
# 7              4.44  {u'profile': 2, u'cute': 4, u'funny': 2, u'pla...
# 8              3.86               {u'plain': 5, u'hot': 1, u'cool': 1}
# 9              3.55  {u'profile': 1, u'cute': 1, u'funny': 8, u'pla...
# 10             4.30  {u'photos': 1, u'hot': 1, u'plain': 2, u'cool'...
# 11             4.02  {u'profile': 10, u'cute': 82, u'funny': 70, u'...
# ...

# %%
merged_df = pd.merge(review_df, user_df, on='user_id', how='inner')

# %%
merged_df.shape
# Out:
# (2, 18)

# %%
list(merged_df.columns.values)
# Out:
# [u'business_id_x',
#  u'date_x',
#  u'review_id_x',
#  u'stars_x',
#  u'text_x',
#  u'type_x',
#  u'user_id',
#  u'votes_x',
#  u'business_id_y',
#  u'date_y',
#  u'review_id_y',
#  u'stars_y',
#  u'text_y',
#  u'type_y',
#  u'votes_y']

# %%
data = []
for i, line in enumerate(data_main):
    data = map(lambda x: x.rstrip(), line)

# %%
data
# Out:
# [u'votes',
#  u'user_id',
#  u'review_id',
#  u'text',
#  u'business_id',
#  u'stars',
#  u'date',
#  u'type']

# %%
data_main = []
for i, line in enumerate(data):
    data_main.append(json.loads(line))

# %%
data_main1 = []
for line in data:
    data_main.append(json.loads(line))

# %%
data_main1
# Out:
# []

# %%
data_json_str
# Out:
# '[{"yelping_since": "2004-10", "votes": {"funny": 166, "useful": 278, "cool": 245}, "review_count": 108, "name": "Russel", "user_id": "18kPq7GPye-YQ3LyKyAZPw", "friends": ["rpOyqD_893cqmDAtJLbdog", "4U9kSBLuBDU391x6bxU-YA", "fHtTaujcyKvXglE33Z5yIw", "8J4IIYcqBlFch8T90N923A", "wy6l_zUo7SN0qrvNRWgySw", "HDQixQ-WZEV0LVPJlIGQeQ", "T4kuUr_iJiywOPdyM7gTHQ", "z_5D4XEIlGAPjG3Os9ix5A", "i63u3SdbrLsP4FxiSKP0Zw", "pnrGw4ciBXJ6U5QB2m0F5g", "ytjCBxosVSqCOQ62c4KAxg", "r5uiIxwJ-I-oHBkNY2Ha3Q", "niWoSKswEbooJC_M7HMbGw", "kwoxiKMyoYjB1wTCYAjYRg", "9A8OuP6XwLwnNb9ov3_Ncw", "27MmRg8LfbZXNEHkEnKSdA", "Bn4sJUTtKFZQt0FKHF2Adw", "uguXfIEpI65jSCH5MgUDgA", "6VZNGc2h2Bn-uyuEXgOt5g", "AZ8CTtwr-4sGM2kZqF6qig", "S742m-AuQicMSLDdErrLZQ", "uGmQ6ab4iVpWn5m61VFhkQ", "GJYJX4SujVj3BR8v2F9PDQ", "3shjifK-vZkIHciyy_KbYA", "4lc_H2Cf7CO0tCgyA3aSVQ", "Tunkp_F1R_uFBJQTsDxD4g", "B9pKfr27czBbCoAIircZdQ", "pePGMO6EbDpbaZ7D2m6HIg", "XRM8W6HUoXbrYKR3BCj9Rg", "8DqIWXsKXOipfduYEfFpNw", "dvRVX54Z9f7Om51NsTRX1w", "CM0saLQmk4oAB17UmQT
# ...

# %%
reviewdata_df
# Out:
#                 business_id       date               review_id  stars  \
# 0    vcNAWiLM4dR7D2nwwJ7nCA 2007-05-17  15SdjuK7DmYqUAj6rjGowg      5
# 1    vcNAWiLM4dR7D2nwwJ7nCA 2010-03-22  RF6UnRTtG7tWMcrO2GEoAg      2
# 2    vcNAWiLM4dR7D2nwwJ7nCA 2012-02-14  -TsVN230RCkLYKBeLsuz7A      4
# 3    vcNAWiLM4dR7D2nwwJ7nCA 2012-03-02  dNocEAyUucjT371NNND41Q      4
# 4    vcNAWiLM4dR7D2nwwJ7nCA 2012-05-15  ebcN2aqmNUuYNoyvQErgnA      4
# 5    vcNAWiLM4dR7D2nwwJ7nCA 2013-04-19  _ePLBPrkrf4bhyiKWEn4Qg      1
# 6    vcNAWiLM4dR7D2nwwJ7nCA 2014-01-02  kMu0knsSUFW2DZXqKkGWlg      5
# 7    vcNAWiLM4dR7D2nwwJ7nCA 2014-01-08  onDPFgNZpMk-bT1zlForRA      5
# 8    vcNAWiLM4dR7D2nwwJ7nCA 2014-08-01  bOJD0Kc3wGioat3oSFqgPQ      1
# 9    vcNAWiLM4dR7D2nwwJ7nCA 2014-12-12  QzjRXUNSGk3PySEcg5y92g      5
# 10   UsFtqoBl7naz8AVUBZMjQQ 2013-11-08  Di3exaUCFNw1V4kSNW5pgA      5
# 11   UsFtqoBl7naz8AVUBZMjQQ 2014-03-29  0Lua2-PbqEQMjD9r89-asw      3
# ...

# %%
# read the entire file into a python array
with open('C:\Users\Shubhanshu\Desktop\yelp\\userdata.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
userdata_df = pd.read_json(data_json_str)

# %%
merged_df = pd.merge(reviewdata_df, userdata_df, on='user_id', how='inner')

# %%
merged_df
# Out:
#               business_id       date               review_id  stars  \
# 0  b9WZJp5L1RZr4F1nxclOoQ 2014-09-30  MTZKEsU_0zZe5XEBoNZHOA      5
# 1  sRqB6flj3GtTZIZJQxf_oA 2010-02-12  4eldjuGqNwHtDXpgcFMPug      1
#
#                                                 text  type_x  \
# 0  What a find! I stopped in here for breakfast w...  review
# 1  We had the worst possible experience at the Ea...  review
#
#                   user_id                                  votes_x  \
# 0  1Hx--oyAcojSfqQYERNkig  {u'funny': 0, u'useful': 1, u'cool': 1}
# 1  zcZ_QLGy6yaFtVYzViFWNw  {u'funny': 0, u'useful': 0, u'cool': 0}
#
#    average_stars    compliments elite  fans                   friends    name  \
# 0              5  {u'plain': 1}    []     0  [OizQLYmpq9kKYs-7ehTpFw]     Amy
# 1              1             {}    []     0                        []  Lokesh
#
#    review_count type_y                                  votes_y yelping_since
# ...

# %%
list(merged_df.columns.values)
# Out:
# [u'business_id',
#  u'date',
#  u'review_id',
#  u'stars',
#  u'text',
#  u'type_x',
#  u'user_id',
#  u'votes_x',
#  u'average_stars',
#  u'compliments',
#  u'elite',
#  u'fans',
#  u'friends',
#  u'name',
#  u'review_count',
#  u'type_y',
#  u'votes_y',
#  u'yelping_since']

# %%
merged_df.shape
# Out:
# (2, 18)

# %%
merged = pd.read_csv("C:\Users\Shubhanshu\Desktop\yelp\merged_dataframe.csv", error_bad_lines=False)
# Out:
# Skipping line 11: expected 17 fields, saw 18
# Skipping line 32: expected 17 fields, saw 23
# Skipping line 33: expected 17 fields, saw 18
# Skipping line 45: expected 17 fields, saw 19
# Skipping line 46: expected 17 fields, saw 23
# Skipping line 47: expected 17 fields, saw 21
# Skipping line 48: expected 17 fields, saw 19
# Skipping line 65: expected 17 fields, saw 42
# Skipping line 68: expected 17 fields, saw 42
# Skipping line 72: expected 17 fields, saw 43
# Skipping line 73: expected 17 fields, saw 44
# Skipping line 84: expected 17 fields, saw 42
# Skipping line 89: expected 17 fields, saw 42
# Skipping line 90: expected 17 fields, saw 42
# Skipping line 93: expected 17 fields, saw 42
# Skipping line 100: expected 17 fields, saw 42
# Skipping line 111: expected 17 fields, saw 42
# Skipping line 123: expected 17 fields, saw 43
# Skipping line 128: expected 17 fields, saw 44
# Skipping line 133: expected 17 fields, saw 42
# Skipping line 139: expected 17 fields, saw 42
# ...

# %%
merged
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     \tbusiness_id\tdate\treview_id\tstars\ttext\ttype_x\tuser_id\tvotes_x\taverage_stars\tcompliments\telite\tfans\tfriends\tname\treview_count\ttype_y\tvotes_y\tyelping_since
# ...

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ...:                           'foo', 'bar', 'foo', 'foo'],
   ...:                    'B' : ['one', 'one', 'two', 'three',
   ...:                           'two', 'two', 'one', 'three'],
   ...:                    'C' : np.random.randn(8),
   ...:                    'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  1.911072  1.096939
# 1  bar    one -1.380197 -0.497903
# 2  foo    two -0.331073 -0.740249
# 3  bar  three -0.850891  0.890841
# 4  foo    two  1.935950 -1.289028
# 5  bar    two -0.794406  1.628775
# 6  foo    one  0.294352 -1.408441
# 7  foo  three -1.824745 -1.825558

# %%
df_grp = df.groupby('A')

# %%
df_grp

# %%
df_grp.first()
# Out:
#        B         C         D
# A
# bar  one -1.380197 -0.497903
# foo  one  1.911072  1.096939

# %%
df_grp.sum()
# Out:
#             C         D
# A
# bar -3.025494  2.021713
# foo  1.985556 -4.166336

# %%
grouped = merged_df.groupby('stars')

# %%
grouped.sum()
# Out:
#        average_stars  fans  review_count
# stars
# 1                  1     0             3
# 5                  5     0             1

# %%
grouped.groups
# Out:
# {1: [1L], 5: [0L]}

# %%
grouped.size()
# Out:
# stars
# 1    1
# 5    1
# dtype: int64

# %%
grouped_1 = merged_df.groupby('stars')['stars'].agg({'Frequency':'count'})

# %%
grouped_1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E13CAC8>]], dtype=object)

# %%
plt.hist(grouped, bins=2)
plt.title("Gaussian Histogram")
plt.xlabel("Stars")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-660faef593e1> in <module>()
# ----> 1 plt.hist(grouped, bins=2)
#       2 plt.title("Gaussian Histogram")
#       3 plt.xlabel("Stars")
#       4 plt.ylabel("Frequency")
#       5 plt.show()
#
# F:\PythonIDE\lib\site-packages\matplotlib\pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# ...

# %%
merged_dataset = pd.DataFrame('C:\Users\Shubhanshu\Desktop\yelp\out.txt')
# Out:
# ---------------------------------------------------------------------------
# PandasError                               Traceback (most recent call last)
# <ipython-input-47-2e544f1fade1> in <module>()
# ----> 1 merged_dataset = pd.DataFrame('C:\Users\Shubhanshu\Desktop\yelp\out.txt')
#
# F:\PythonIDE\lib\site-packages\pandas\core\frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     302                                          copy=False)
#     303             else:
# --> 304                 raise PandasError('DataFrame constructor not properly called!')
#     305
#     306         NDFrame.__init__(self, mgr, fastpath=True)
#
# PandasError: DataFrame constructor not properly called!

# %%
merged_data = []
with open('C:\Users\Shubhanshu\Desktop\yelp\out.txt', 'rb') as f:
    for line in f:
        merged_data.append(json.loads(line))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-5b4af6d43f46> in <module>()
#       2 with open('C:\Users\Shubhanshu\Desktop\yelp\out.txt', 'rb') as f:
#       3     for line in f:
# ----> 4         merged_data.append(json.loads(line))
#
# F:\PythonIDE\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# F:\PythonIDE\lib\json\decoder.pyc in decode(self, s, _w)
#     364
#     365         """
# --> 366         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     367         end = _w(s, end).end()
# ...

# %%
lines = text_file.read().split(',')

# %%
with open('C:\Users\Shubhanshu\Desktop\yelp\out.txt', 'rb') as f:
    x = f.readlines()

# %%
list_of_lists = []
with open('C:\Users\Shubhanshu\Desktop\yelp\out.txt') as f:
    for line in f:
        inner_list = [elt.strip() for elt in line.split(',')]
        # in alternative, if you need to use the file content as numbers
        # inner_list = [int(elt.strip()) for elt in line.split(',')]
        list_of_lists.append(inner_list)

# %%
list_of_lists
# Out:
# [["{u'votes': {u'funny': 0",
#   "u'useful': 0",
#   "u'cool': 0}",
#   "u'user_id': u'PUFPaY9KxDAcGqfsorJp3Q'",
#   "u'review_id': u'Ya85v4eqdd6k9Od8HbQjyA'",
#   "u'text': u'Mr Hoagie is an institution. Walking in",
#   'it does seem like a throwback to 30 years ago',
#   'old fashioned menu board',
#   'booths out of the 70s',
#   'and a large selection of food. Their speciality is the Italian Hoagie',
#   'and it is voted the best in the area year after year. I usually order the burger',
#   'while the patties are obviously cooked from frozen',
#   'all of the other ingredients are very fresh. Overall',
#   'its a good alternative to Subway',
#   "which is down the road.'",
#   "u'business_id': u'5UmKMjUEUNdYWqANhGckJw'",
#   "u'stars': 4",
#   "u'date': u'2012-08-01'",
#   "u'type': u'review'}"],
#  ["{u'votes': {u'funny': 0",
#   "u'useful': 0",
#   "u'cool': 0}",
#   "u'user_id': u'Iu6AxdBYGR4A0wspR9BYHA'",
#   "u'review_id': u'KPvLNJ21_4wbYNctrOwWdQ'",
# ...

# %%
merged_data = pd.DataFrame(list_of_lists)

# %%
merged_data
# Out:
#                           0             1            2   \
# 0    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 1    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 2    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 3    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 4    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 5    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 6    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 7    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 8    {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 9    {u'votes': {u'funny': 0  u'useful': 1  u'cool': 0}
# 10   {u'votes': {u'funny': 0  u'useful': 1  u'cool': 0}
# 11   {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 12   {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 13   {u'votes': {u'funny': 0  u'useful': 0  u'cool': 0}
# 14   {u'votes': {u'funny': 3  u'useful': 7  u'cool': 7}
# 15   {u'votes': {u'funny': 1  u'useful': 1  u'cool': 1}
# ...

# %%
panda = pd.DataFrame('C:\Users\Shubhanshu\Desktop\yelp\out.txt',delim_whitespace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-2803b688ef6e> in <module>()
# ----> 1 panda = pd.DataFrame('C:\Users\Shubhanshu\Desktop\yelp\out.txt',delim_whitespace=True)
#
# TypeError: __init__() got an unexpected keyword argument 'delim_whitespace'

# %%
text_file = open('C:\Users\Shubhanshu\Desktop\yelp\out.txt', 'r')
lines = text_file.read().split(',')

# %%
merged_data = pd.DataFrame(lines)

# %%
merged_data
# Out:
#                                                        0
# 0                                {u'votes': {u'funny': 0
# 1                                           u'useful': 0
# 2                                            u'cool': 0}
# 3                  u'user_id': u'PUFPaY9KxDAcGqfsorJp3Q'
# 4                u'review_id': u'Ya85v4eqdd6k9Od8HbQjyA'
# 5       u'text': u'Mr Hoagie is an institution. Walki...
# 6          it does seem like a throwback to 30 years ago
# 7                               old fashioned menu board
# 8                                  booths out of the 70s
# 9       and a large selection of food. Their speciali...
# 10      and it is voted the best in the area year aft...
# 11      while the patties are obviously cooked from f...
# 12      all of the other ingredients are very fresh. ...
# 13                      its a good alternative to Subway
# 14                              which is down the road.'
# ...

# %%
yo = grouped_1['Frequency'].hist()

# %%
plt.show()

# %%
for group in merged_df:
  figure()
  matplotlib.pyplot.hist(group[1].stars)
  show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-d8deb1cebebf> in <module>()
#       1 for group in merged_df:
# ----> 2   figure()
#       3   matplotlib.pyplot.hist(group[1].stars)
#       4   show()
#
# NameError: name 'figure' is not defined
