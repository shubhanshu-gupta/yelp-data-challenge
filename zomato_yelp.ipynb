# %%
import json
import string
import Sys
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-72-6d1a1cc4b6db> in <module>()
#       1 import json
#       2 import string
# ----> 3 import Sys
#
# ImportError: No module named Sys

# %%
data = []
with open('C:\Users\Shubhanshu\Desktop\userdata.json') as f:
    for line in f:
        data.append(json.loads(line))

# %%
print data
# Out:
# [{u'yelping_since': u'2004-10', u'votes': {u'funny': 166, u'useful': 278, u'cool': 245}, u'user_id': u'18kPq7GPye-YQ3LyKyAZPw', u'name': u'Russel', u'elite': [2005, 2006], u'type': u'user', u'compliments': {u'profile': 8, u'cute': 15, u'funny': 11, u'plain': 25, u'writer': 9, u'note': 20, u'photos': 15, u'hot': 48, u'more': 3, u'cool': 78}, u'fans': 69, u'average_stars': 4.14, u'review_count': 108, u'friends': [u'rpOyqD_893cqmDAtJLbdog', u'4U9kSBLuBDU391x6bxU-YA', u'fHtTaujcyKvXglE33Z5yIw', u'8J4IIYcqBlFch8T90N923A', u'wy6l_zUo7SN0qrvNRWgySw', u'HDQixQ-WZEV0LVPJlIGQeQ', u'T4kuUr_iJiywOPdyM7gTHQ', u'z_5D4XEIlGAPjG3Os9ix5A', u'i63u3SdbrLsP4FxiSKP0Zw', u'pnrGw4ciBXJ6U5QB2m0F5g', u'ytjCBxosVSqCOQ62c4KAxg', u'r5uiIxwJ-I-oHBkNY2Ha3Q', u'niWoSKswEbooJC_M7HMbGw', u'kwoxiKMyoYjB1wTCYAjYRg', u'9A8OuP6XwLwnNb9ov3_Ncw', u'27MmRg8LfbZXNEHkEnKSdA', u'Bn4sJUTtKFZQt0FKHF2Adw', u'uguXfIEpI65jSCH5MgUDgA', u'6VZNGc2h2Bn-uyuEXgOt5g', u'AZ8CTtwr-4sGM2kZqF6qig', u'S742m-AuQicMSLDdErrLZQ', u'uGmQ6ab4iVpWn5
# ...

# %%
def getunicode(soup):
	body=''
	if isinstance(soup, unicode):
	    soup = soup.replace('&#39;',"'")
	    soup = soup.replace('&quot;','"')
	    soup = soup.replace('&nbsp;',' ')
	    body = body + soup
	else:
	    if not soup.contents:
	        return ''
	    con_list = soup.contents
	    for con in con_list:
	        body = body + getunicode(con)
	return body

# %%
data = []
my_dict = {}

    with open('C:\Users\Shubhanshu\Desktop\userdata.json') as f:
        for line in f:
            jdata = json.loads(line)
            for d in jdata:
                for key, value in d.iteritems():
                    if key not in da:
                        my_dict[key] = value
                    else:
                        my_dict = {}
                        my_dict[key] = value
                data.append(da)
# Out:
#   File "<ipython-input-75-edde56f372c0>", line 4
#     with open('C:\Users\Shubhanshu\Desktop\userdata.json') as f:
#     ^
# IndentationError: unexpected indent

# %%
data = []
my_dict = {}

with open('C:\Users\Shubhanshu\Desktop\userdata.json') as f:
    for line in f:
        jdata = json.loads(line)
        #print jdata
        for d in jdata:
            for key, value in d.iteritems():
                if key not in my_dict:
                    my_dict[key] = value
                else:
                    my_dict = {}
                    my_dict[key] = value
            data.append(my_dict)                    

#print data[0]["yelping_since"]
# Out:
# {u'yelping_since': u'2004-10', u'votes': {u'funny': 166, u'useful': 278, u'cool': 245}, u'user_id': u'18kPq7GPye-YQ3LyKyAZPw', u'name': u'Russel', u'elite': [2005, 2006], u'type': u'user', u'compliments': {u'profile': 8, u'cute': 15, u'funny': 11, u'plain': 25, u'writer': 9, u'note': 20, u'photos': 15, u'hot': 48, u'more': 3, u'cool': 78}, u'fans': 69, u'average_stars': 4.14, u'review_count': 108, u'friends': [u'rpOyqD_893cqmDAtJLbdog', u'4U9kSBLuBDU391x6bxU-YA', u'fHtTaujcyKvXglE33Z5yIw', u'8J4IIYcqBlFch8T90N923A', u'wy6l_zUo7SN0qrvNRWgySw', u'HDQixQ-WZEV0LVPJlIGQeQ', u'T4kuUr_iJiywOPdyM7gTHQ', u'z_5D4XEIlGAPjG3Os9ix5A', u'i63u3SdbrLsP4FxiSKP0Zw', u'pnrGw4ciBXJ6U5QB2m0F5g', u'ytjCBxosVSqCOQ62c4KAxg', u'r5uiIxwJ-I-oHBkNY2Ha3Q', u'niWoSKswEbooJC_M7HMbGw', u'kwoxiKMyoYjB1wTCYAjYRg', u'9A8OuP6XwLwnNb9ov3_Ncw', u'27MmRg8LfbZXNEHkEnKSdA', u'Bn4sJUTtKFZQt0FKHF2Adw', u'uguXfIEpI65jSCH5MgUDgA', u'6VZNGc2h2Bn-uyuEXgOt5g', u'AZ8CTtwr-4sGM2kZqF6qig', u'S742m-AuQicMSLDdErrLZQ', u'uGmQ6ab4iVpWn5m
# ...

# %%
data = []

with open('C:\Users\Shubhanshu\Desktop\userdata.json') as f:
    for line in f:
        for item in json.loads(line):
            my_dict={}
            item1 = item.decode("utf-8")
            #item1 = item.encode('utf-8')
            print item1
            #my_dict['user']=item1.get('user_id')
            #my_dict['user_ratings']=item.get('average_stars')
            #my_dict['friends']=item.get('friends')
            #my_dict['elite']=item.get('elite')
            #print my_dict
            #data.append(my_dict)
        #data.append(json.loads(line))
# Out:
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# compliments
# fans
# average_stars
# review_count
# friends
# yelping_since
# votes
# user_id
# name
# elite
# type
# ...

# %%
from json import JSONDecoder
from functools import partial


def json_parse(fileobj, decoder=JSONDecoder(), buffersize=2048):
    buffer = ''
    for chunk in iter(partial(fileobj.read, buffersize), ''):
         buffer += chunk
         while buffer:
             try:
                 result, index = decoder.raw_decode(buffer)
                 yield result
                 buffer = buffer[index:]
             except ValueError:
                 # Not enough data to decode, read more
                 break

# %%
list(json_parse(open('C:\Users\Shubhanshu\Desktop\userdata.json')))
# Out:
# [{u'average_stars': 4.14,
#   u'compliments': {u'cool': 78,
#    u'cute': 15,
#    u'funny': 11,
#    u'hot': 48,
#    u'more': 3,
#    u'note': 20,
#    u'photos': 15,
#    u'plain': 25,
#    u'profile': 8,
#    u'writer': 9},
#   u'elite': [2005, 2006],
#   u'fans': 69,
#   u'friends': [u'rpOyqD_893cqmDAtJLbdog',
#    u'4U9kSBLuBDU391x6bxU-YA',
#    u'fHtTaujcyKvXglE33Z5yIw',
#    u'8J4IIYcqBlFch8T90N923A',
#    u'wy6l_zUo7SN0qrvNRWgySw',
#    u'HDQixQ-WZEV0LVPJlIGQeQ',
#    u'T4kuUr_iJiywOPdyM7gTHQ',
#    u'z_5D4XEIlGAPjG3Os9ix5A',
#    u'i63u3SdbrLsP4FxiSKP0Zw',
#    u'pnrGw4ciBXJ6U5QB2m0F5g',
#    u'ytjCBxosVSqCOQ62c4KAxg',
#    u'r5uiIxwJ-I-oHBkNY2Ha3Q',
#    u'niWoSKswEbooJC_M7HMbGw',
#    u'kwoxiKMyoYjB1wTCYAjYRg',
#    u'9A8OuP6XwLwnNb9ov3_Ncw',
#    u'27MmRg8LfbZXNEHkEnKSdA',
#    u'Bn4sJUTtKFZQt0FKHF2Adw',
#    u'uguXfIEpI65jSCH5MgUDgA',
#    u'6VZNGc2h2Bn-uyuEXgOt5g',
#    u'AZ8CTtwr-4sGM2kZqF6qig',
#    u'S742m-AuQicMSLDdErrLZQ',
#    u'uGmQ6ab4iVpWn5m61VFhkQ',
# ...

# %%
with open('C:\Users\Shubhanshu\Desktop\userdata.json', 'r') as infh:
    for data in json_parse(infh):
        # process object
        print data
# Out:
# {u'yelping_since': u'2004-10', u'votes': {u'funny': 166, u'useful': 278, u'cool': 245}, u'user_id': u'18kPq7GPye-YQ3LyKyAZPw', u'name': u'Russel', u'elite': [2005, 2006], u'type': u'user', u'compliments': {u'profile': 8, u'cute': 15, u'funny': 11, u'plain': 25, u'writer': 9, u'note': 20, u'photos': 15, u'hot': 48, u'more': 3, u'cool': 78}, u'fans': 69, u'average_stars': 4.14, u'review_count': 108, u'friends': [u'rpOyqD_893cqmDAtJLbdog', u'4U9kSBLuBDU391x6bxU-YA', u'fHtTaujcyKvXglE33Z5yIw', u'8J4IIYcqBlFch8T90N923A', u'wy6l_zUo7SN0qrvNRWgySw', u'HDQixQ-WZEV0LVPJlIGQeQ', u'T4kuUr_iJiywOPdyM7gTHQ', u'z_5D4XEIlGAPjG3Os9ix5A', u'i63u3SdbrLsP4FxiSKP0Zw', u'pnrGw4ciBXJ6U5QB2m0F5g', u'ytjCBxosVSqCOQ62c4KAxg', u'r5uiIxwJ-I-oHBkNY2Ha3Q', u'niWoSKswEbooJC_M7HMbGw', u'kwoxiKMyoYjB1wTCYAjYRg', u'9A8OuP6XwLwnNb9ov3_Ncw', u'27MmRg8LfbZXNEHkEnKSdA', u'Bn4sJUTtKFZQt0FKHF2Adw', u'uguXfIEpI65jSCH5MgUDgA', u'6VZNGc2h2Bn-uyuEXgOt5g', u'AZ8CTtwr-4sGM2kZqF6qig', u'S742m-AuQicMSLDdErrLZQ', u'uGmQ6ab4iVpWn5m
# ...

# %%
list(json_parse(open('C:\Users\Shubhanshu\Desktop\userdata.json')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-171c60cef01e> in <module>()
# ----> 1 list(json_parse(open('C:\Users\Shubhanshu\Desktop\userdata.json')))
#
# <ipython-input-20-ee2c58fc2e4c> in json_parse(fileobj, decoder, buffersize, delimiters)
#       2                delimiters=None):
#       3     remainder = ''
# ----> 4     for chunk in iter(functools.partial(fileobj.read, buffersize), ''):
#       5         remainder += chunk
#       6         while remainder:
#
# NameError: global name 'functools' is not defined

# %%
input_file=open("C:\Users\Shubhanshu\Desktop\userdata.json").readlines()
#output_file=open('test.json', 'w')

# %%
interim = string.split(input_file, '\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cbd9c5e8398f> in <module>()
# ----> 1 interim = string.split(input_file, '\n')
#
# F:\PythonIDE\lib\string.pyc in split(s, sep, maxsplit)
#     292
#     293     """
# --> 294     return s.split(sep, maxsplit)
#     295 splitfields = split
#     296
#
# AttributeError: 'list' object has no attribute 'split'

# %%
json_decode=json.load(input_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d1d3edb1a178> in <module>()
# ----> 1 json_decode=json.load(input_file)
#
# F:\PythonIDE\lib\json\__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     288         parse_float=parse_float, parse_int=parse_int,
#     289         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 290         **kw)
#     291
#     292
#
# F:\PythonIDE\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
# ...

# %%
import json
import pandas as pd
from glob import glob

def convert(x):
    ''' Convert a json string to a flat python dictionary
    which can be passed into Pandas. '''
    ob = json.loads("C:\Users\Shubhanshu\Desktop\userdata.json")
    for k, v in ob.items():
        if isinstance(v, list):
            ob[k] = ','.join(str(v))
        elif isinstance(v, dict):
            for kk, vv in v.items():
                ob['%s_%s' % (k, kk)] = vv
            del ob[k]
    return ob

for json_filename in glob('*.json'):
    csv_filename = '%s.csv' % json_filename[:-5]
    print 'Converting %s to %s' % (json_filename, csv_filename)
    df = pd.DataFrame([convert(line) for line in file(json_filename)])
    df.to_csv(csv_filename, encoding='utf-8', index=False)

# %%
import json
from pprint import pprint

with open("C:\Users\Shubhanshu\Desktop\userdata.json") as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-29a434496092> in <module>()
#       3
#       4 with open("C:\Users\Shubhanshu\Desktop\userdata.json") as data_file:
# ----> 5     data = json.load(data_file)
#       6
#       7 pprint(data)
#
# F:\PythonIDE\lib\json\__init__.pyc in load(fp, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     288         parse_float=parse_float, parse_int=parse_int,
#     289         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook,
# --> 290         **kw)
#     291
#     292
#
# F:\PythonIDE\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
# ...
